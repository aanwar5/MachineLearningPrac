# %%
import pandas as pd

# %%
df = pd.read_csv('C:\\Users\\Dell\\Downloads\\AB_NYC_2019.csv')

# %%
df.head(10)
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
# 5  5099         Large Cozy 1 BR Apartment In Midtown East     7322
# 6  5121                                   BlissArtsSpace!     7356
# 7  5178                  Large Furnished Room Near B'way      8967
# 8  5203                Cozy Clean Guest Room - Family Apt     7490
# 9  5238                Cute & Cozy Lower East Side 1 bdrm     7549
#
#      host_name neighbourhood_group       neighbourhood  latitude  longitude  \
# 0         John            Brooklyn          Kensington  40.64749  -73.97237
# ...

# %%
df.shape
# Out:
# (48895, 16)

# %%
df.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %%
df.dtypes
# Out:
# id                                  int64
# name                               object
# host_id                             int64
# host_name                          object
# neighbourhood_group                object
# neighbourhood                      object
# latitude                          float64
# longitude                         float64
# room_type                          object
# price                               int64
# minimum_nights                      int64
# number_of_reviews                   int64
# last_review                        object
# reviews_per_month                 float64
# calculated_host_listings_count      int64
# availability_365                    int64
# dtype: object

# %%
df.isnull().sum() #how to check whether the data is clean
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
columns_to_drop = ['id', 'host_name', 'last_review']
df.drop(columns_to_drop, axis = 'columns', inplace = True)

# %%
df.isnull().sum() #how to check whether the data is clean
# Out:
# name                                 16
# host_id                               0
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
df.head()
# Out:
#                                                name  host_id  \
# 0                Clean & quiet apt home by the park     2787
# 1                             Skylit Midtown Castle     2845
# 2               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3                   Cozy Entire Floor of Brownstone     4869
# 4  Entire Apt: Spacious Studio/Loft by central park     7192
#
#   neighbourhood_group neighbourhood  latitude  longitude        room_type  \
# 0            Brooklyn    Kensington  40.64749  -73.97237     Private room
# 1           Manhattan       Midtown  40.75362  -73.98377  Entire home/apt
# 2           Manhattan        Harlem  40.80902  -73.94190     Private room
# 3            Brooklyn  Clinton Hill  40.68514  -73.95976  Entire home/apt
# 4           Manhattan   East Harlem  40.79851  -73.94399  Entire home/apt
#
#    price  minimum_nights  number_of_reviews  reviews_per_month  \
# 0    149               1                  9               0.21
# ...

# %%
df.fillna({'reviews_per_month' : 0}, inplace = True) #replacing missing data/NAN's with 0

# %%
df.head()
# Out:
#                                                name  host_id  \
# 0                Clean & quiet apt home by the park     2787
# 1                             Skylit Midtown Castle     2845
# 2               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3                   Cozy Entire Floor of Brownstone     4869
# 4  Entire Apt: Spacious Studio/Loft by central park     7192
#
#   neighbourhood_group neighbourhood  latitude  longitude        room_type  \
# 0            Brooklyn    Kensington  40.64749  -73.97237     Private room
# 1           Manhattan       Midtown  40.75362  -73.98377  Entire home/apt
# 2           Manhattan        Harlem  40.80902  -73.94190     Private room
# 3            Brooklyn  Clinton Hill  40.68514  -73.95976  Entire home/apt
# 4           Manhattan   East Harlem  40.79851  -73.94399  Entire home/apt
#
#    price  minimum_nights  number_of_reviews  reviews_per_month  \
# 0    149               1                  9               0.21
# ...

# %%
df[['name', 'neighbourhood_group', 'price']] #3 specific headers
# Out:
#                                                     name neighbourhood_group  \
# 0                     Clean & quiet apt home by the park            Brooklyn
# 1                                  Skylit Midtown Castle           Manhattan
# 2                    THE VILLAGE OF HARLEM....NEW YORK !           Manhattan
# 3                        Cozy Entire Floor of Brownstone            Brooklyn
# 4       Entire Apt: Spacious Studio/Loft by central park           Manhattan
# ...                                                  ...                 ...
# 48890    Charming one bedroom - newly renovated rowhouse            Brooklyn
# 48891      Affordable room in Bushwick/East Williamsburg            Brooklyn
# 48892            Sunny Studio at Historical Neighborhood           Manhattan
# 48893               43rd St. Time Square-cozy single bed           Manhattan
# 48894  Trendy duplex in the very heart of Hell's Kitchen           Manhattan
#
#        price
# 0        149
# 1        225
# ...

# %%
df[0:8] #taking out first 8 rows
# Out:
#                                                name  host_id  \
# 0                Clean & quiet apt home by the park     2787
# 1                             Skylit Midtown Castle     2845
# 2               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3                   Cozy Entire Floor of Brownstone     4869
# 4  Entire Apt: Spacious Studio/Loft by central park     7192
# 5         Large Cozy 1 BR Apartment In Midtown East     7322
# 6                                   BlissArtsSpace!     7356
# 7                  Large Furnished Room Near B'way      8967
#
#   neighbourhood_group       neighbourhood  latitude  longitude  \
# 0            Brooklyn          Kensington  40.64749  -73.97237
# 1           Manhattan             Midtown  40.75362  -73.98377
# 2           Manhattan              Harlem  40.80902  -73.94190
# 3            Brooklyn        Clinton Hill  40.68514  -73.95976
# 4           Manhattan         East Harlem  40.79851  -73.94399
# ...

# %%
df['price'] < 100 #shall only create boolean
# Out:
# 0        False
# 1        False
# 2        False
# 3         True
# 4         True
#          ...
# 48890     True
# 48891     True
# 48892    False
# 48893     True
# 48894     True
# Name: price, Length: 48895, dtype: bool

# %%
df[df['price'] < 100] #creates data frame
# Out:
#                                                     name    host_id  \
# 3                        Cozy Entire Floor of Brownstone       4869
# 4       Entire Apt: Spacious Studio/Loft by central park       7192
# 6                                        BlissArtsSpace!       7356
# 7                       Large Furnished Room Near B'way        8967
# 8                     Cozy Clean Guest Room - Family Apt       7490
# ...                                                  ...        ...
# 48889                                 QUIT PRIVATE HOUSE  107716952
# 48890    Charming one bedroom - newly renovated rowhouse    8232441
# 48891      Affordable room in Bushwick/East Williamsburg    6570630
# 48893               43rd St. Time Square-cozy single bed   30985759
# 48894  Trendy duplex in the very heart of Hell's Kitchen   68119814
#
#       neighbourhood_group       neighbourhood  latitude  longitude  \
# 3                Brooklyn        Clinton Hill  40.68514  -73.95976
# ...

# %%
df[df['price'] < 100].shape #only 21877 rows are lesser than 100
# Out:
# (21877, 13)

# %% [markdown]
# ###What are the 10 most reviewed listings ?###

# %%
df.head()
# Out:
#                                                name  host_id  \
# 0                Clean & quiet apt home by the park     2787
# 1                             Skylit Midtown Castle     2845
# 2               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3                   Cozy Entire Floor of Brownstone     4869
# 4  Entire Apt: Spacious Studio/Loft by central park     7192
#
#   neighbourhood_group neighbourhood  latitude  longitude        room_type  \
# 0            Brooklyn    Kensington  40.64749  -73.97237     Private room
# 1           Manhattan       Midtown  40.75362  -73.98377  Entire home/apt
# 2           Manhattan        Harlem  40.80902  -73.94190     Private room
# 3            Brooklyn  Clinton Hill  40.68514  -73.95976  Entire home/apt
# 4           Manhattan   East Harlem  40.79851  -73.94399  Entire home/apt
#
#    price  minimum_nights  number_of_reviews  reviews_per_month  \
# 0    149               1                  9               0.21
# ...

# %%
df.nlargest(10, 'number_of_reviews') #top 10 largest reviews
# Out:
#                                                     name   host_id  \
# 11759                            Room near JFK Queen Bed  47621202
# 2031                          Great Bedroom in Manhattan   4734398
# 2030                      Beautiful Bedroom in Manhattan   4734398
# 2015                        Private Bedroom in Manhattan   4734398
# 13495                            Room Near JFK Twin Beds  47621202
# 10623                  Steps away from Laguardia airport  37312959
# 1879            Manhattan Lux Loft.Like.Love.Lots.Look !   2369681
# 20403  Cozy Room Family Home LGA Airport NO CLEANING FEE  26432133
# 4870                  Private brownstone studio Brooklyn  12949460
# 471                      LG Private Room/Family Friendly    792159
#
#       neighbourhood_group    neighbourhood  latitude  longitude  \
# 11759              Queens          Jamaica  40.66730  -73.76831
# 2031            Manhattan           Harlem  40.82085  -73.94025
# ...

# %%
df['neighbourhood_group'].unique()
# Out:
# array(['Brooklyn', 'Manhattan', 'Queens', 'Staten Island', 'Bronx'],
#       dtype=object)

# %%
df['neighbourhood_group'].value_counts() #most amount of airbnbs in neighbourhood group
# Out:
# Manhattan        21661
# Brooklyn         20104
# Queens            5666
# Bronx             1091
# Staten Island      373
# Name: neighbourhood_group, dtype: int64

# %%
df['neighbourhood'].value_counts().head(10) #top 10 neighbourhoods
# Out:
# Williamsburg          3920
# Bedford-Stuyvesant    3714
# Harlem                2658
# Bushwick              2465
# Upper West Side       1971
# Hell's Kitchen        1958
# East Village          1853
# Upper East Side       1798
# Crown Heights         1564
# Midtown               1545
# Name: neighbourhood, dtype: int64

# %%
df['neighbourhood'].value_counts().head(10).plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %%
import seaborn as sns
order = df['neighbourhood_group'].value_counts().index
sns.countplot(data = df, x = 'neighbourhood_group', order = order)
# Out:
# <AxesSubplot:xlabel='neighbourhood_group', ylabel='count'>

# %%
df['room_type'].unique()
sns.countplot(data = df, x = "neighbourhood_group", hue = 'room_type')
# Out:
# <AxesSubplot:xlabel='neighbourhood_group', ylabel='count'>

# %%
sns.distplot(df['price'])
# Out:
# <AxesSubplot:xlabel='price'>

# %%
newdf = df[df['price'] <= 500]

# %%
sns.distplot(newdf['price'])
# Out:
# <AxesSubplot:xlabel='price'>

# %%
newdf['price'].mean() #avg prices of houses
# Out:
# 131.53056362458466

# %%
#Distrubution of flat prices based on the beighbourhood group ?

# %%
plt.figure(figsize = (15,8))
sns.violinplot(data = newdf, x = 'neighbourhood_group', y = 'price')
# Out:
# <AxesSubplot:xlabel='neighbourhood_group', ylabel='price'>

# %%
from matplotlib import pyplot as plt

# %%
newdf.head()
# Out:
#                                                name  host_id  \
# 0                Clean & quiet apt home by the park     2787
# 1                             Skylit Midtown Castle     2845
# 2               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3                   Cozy Entire Floor of Brownstone     4869
# 4  Entire Apt: Spacious Studio/Loft by central park     7192
#
#   neighbourhood_group neighbourhood  latitude  longitude        room_type  \
# 0            Brooklyn    Kensington  40.64749  -73.97237     Private room
# 1           Manhattan       Midtown  40.75362  -73.98377  Entire home/apt
# 2           Manhattan        Harlem  40.80902  -73.94190     Private room
# 3            Brooklyn  Clinton Hill  40.68514  -73.95976  Entire home/apt
# 4           Manhattan   East Harlem  40.79851  -73.94399  Entire home/apt
#
#    price  minimum_nights  number_of_reviews  reviews_per_month  \
# 0    149               1                  9               0.21
# ...

# %%
newdf.plot(
kind = "scatter",
x = 'longitude',
y = 'latitude',
cmap = 'inferno',
colorbar = True,
alpha = 0.8,
figsize = (12,8)
)
# Out:
# <AxesSubplot:xlabel='longitude', ylabel='latitude'>
